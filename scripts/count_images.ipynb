# %%
import os
from PIL import Image
import numpy as np

# %%
root_dir = './new_data/foggy_deweathered'

count = 0
for root, dirs, files in os.walk(root_dir):
    print(root)
    print(dirs)
    print(files)
    for file in files:
        if file.endswith('.png'):
            count += 1
            img = Image.open(os.path.join(root, file))
            # print(img)
            # img = np.array(img)
            # print(img.shape)
            # print(np.unique(img))
            # print(np.max(img))
            # print(np.min(img))
            # print('-----------------')
            # if count == 1:
            #     break
    # break
print(count)
